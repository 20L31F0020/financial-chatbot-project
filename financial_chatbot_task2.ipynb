# %% [markdown]
# # Financial Chatbot Prototype (Microsoft, Tesla, Apple 2023–2025)
#
# ## Objective:
# Build a simplified AI-powered financial chatbot that answers predefined financial questions based on analyzed 10-K financial data.

# %%
import pandas as pd

data = {
    "Company": ["Microsoft", "Tesla", "Apple"],
    "Avg Revenue": [246.23, 96.43, 396.83],
    "Avg Net Income": [87.43, 8.70, 100.90],
    "Profit Margin": [35.42, 8.99, 25.39]
}

df = pd.DataFrame(data)

print("Financial Summary Data:")
print(df)
# Out:
# Financial Summary Data:
#      Company  Avg Revenue  Avg Net Income  Profit Margin
# 0  Microsoft       246.23           87.43          35.42
# 1      Tesla        96.43            8.70           8.99
# 2      Apple       396.83          100.90          25.39

# %%
def financial_chatbot(user_query):
    query = user_query.lower()

    if query == "what is microsoft's total revenue?":
        return "Microsoft's average total revenue (2023–2025) was $246.23 billion."

    elif query == "what is tesla's total revenue?":
        return "Tesla's average total revenue (2023–2025) was $96.43 billion."

    elif query == "what is apple's total revenue?":
        return "Apple's average total revenue (2023–2025) was $396.83 billion."

    elif query == "which company has the highest profit margin?":
        return "Microsoft had the highest average profit margin at 35.42%."

    elif query == "which company showed the strongest growth?":
        return "Microsoft showed the strongest overall growth from 2023–2025."

    elif query == "which company is the most stable?":
        return "Apple appeared the most stable due to consistent profitability and strong revenue."

    elif query == "help":
        return """
Available Questions:
1. What is Microsoft's total revenue?
2. What is Tesla's total revenue?
3. What is Apple's total revenue?
4. Which company has the highest profit margin?
5. Which company showed the strongest growth?
6. Which company is the most stable?
        """

    else:
        return "Sorry, I can only answer predefined financial questions."

# %%
print("Welcome to the Financial Chatbot Prototype!")
print("Type 'help' for available questions.")
print("Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    response = financial_chatbot(user_input)
    print("Chatbot:", response)
# Out:
# Welcome to the Financial Chatbot Prototype!
# Type 'help' for available questions.
# Type 'exit' to quit.
#
# You: What is Microsoft's total revenue?
# Chatbot: Microsoft's average total revenue (2023–2025) was $246.23 billion.

# %% [markdown]
# # Chatbot Test Results
#
# ## Test 1:
# Question: What is Microsoft's total revenue?
# Answer: Microsoft's average total revenue (2023–2025) was $246.23 billion.
#
# ## Test 2:
# Question: Which company showed the strongest growth?
# Answer: Microsoft showed the strongest overall growth.
#
# ## Test 3:
# Question: Which company is the most stable?
# Answer: Apple appeared the most stable.

# %% [markdown]
# # Documentation Summary
#
# ## How It Works:
# This chatbot uses Python if-elif-else statements to match predefined financial questions with responses based on analyzed financial data.
#
# ## Strengths:
# - Beginner-friendly
# - Simple logic
# - Real financial insights
#
# ## Limitations:
# - No machine learning
# - No natural language understanding
# - Only answers predefined exact questions

# %%
# STEP 10: Save Entire Financial Chatbot as financial_chatbot.py

chatbot_code = '''
# Financial Chatbot Prototype
# Microsoft, Tesla, Apple (2023–2025)

def financial_chatbot(user_query):
    query = user_query.lower()

    if query == "what is microsoft's total revenue?":
        return "Microsoft's average total revenue (2023–2025) was $246.23 billion."

    elif query == "what is tesla's total revenue?":
        return "Tesla's average total revenue (2023–2025) was $96.43 billion."

    elif query == "what is apple's total revenue?":
        return "Apple's average total revenue (2023–2025) was $396.83 billion."

    elif query == "which company has the highest profit margin?":
        return "Microsoft had the highest average profit margin at 35.42%."

    elif query == "which company showed the strongest growth?":
        return "Microsoft showed the strongest overall growth from 2023–2025."

    elif query == "which company is the most stable?":
        return "Apple appeared the most stable due to consistent profitability."

    elif query == "which company is the most volatile?":
        return "Tesla showed the most volatility due to stagnant revenue and declining net income."

    elif query == "help":
        return """
Available Questions:
1. What is Microsoft's total revenue?
2. What is Tesla's total revenue?
3. What is Apple's total revenue?
4. Which company has the highest profit margin?
5. Which company showed the strongest growth?
6. Which company is the most stable?
7. Which company is the most volatile?
        """

    else:
        return "Sorry, I can only answer predefined financial questions."


# Chatbot Interface
print("Welcome to the Financial Chatbot Prototype!")
print("This chatbot analyzes Microsoft, Tesla, and Apple (2023–2025).")
print("Type 'help' to see available questions.")
print("Type 'exit' to quit.\\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    response = financial_chatbot(user_input)
    print("Chatbot:", response)
'''

# Save the chatbot code as a Python file
with open("financial_chatbot.py", "w") as file:
    file.write(chatbot_code)

print("financial_chatbot.py saved successfully!")

# Verify file exists
import os
print("\\nFiles in current folder:")
print(os.listdir())

# Show current save location
print("\\nCurrent folder location:")
print(os.getcwd())

# %%
test_results = """
Financial Chatbot Test Results

Test 1:
User: What is Microsoft's total revenue?
Chatbot: Microsoft's average total revenue (2023–2025) was $246.23 billion.

Test 2:
User: Which company showed the strongest growth?
Chatbot: Microsoft showed the strongest overall growth from 2023–2025.

Test 3:
User: Which company is the most stable?
Chatbot: Apple appeared the most stable due to consistent profitability.

Test 4:
User: Which company is the most volatile?
Chatbot: Tesla showed the most volatility due to stagnant revenue and declining net income.

Test 5:
User: Help
Chatbot: Displayed available predefined questions successfully.
"""

with open("chatbot_test_results.txt", "w") as file:
    file.write(test_results)

print("chatbot_test_results.txt created successfully!")
# Out:
# chatbot_test_results.txt created successfully!

# %%
import os
print("financial_chatbot.py" in os.listdir())
# Out:
# False

# %%
documentation = """
Financial Chatbot Prototype Documentation

Project Objective:
This chatbot prototype was designed to provide simplified financial analysis for Microsoft, Tesla, and Apple (2023–2025) using predefined user queries.

How It Works:
- Uses Python if-elif-else logic
- Matches exact predefined financial questions
- Returns financial insights based on Task 1 analysis

Supported Queries:
- Revenue questions
- Growth questions
- Profitability questions
- Stability/volatility questions

Strengths:
- Beginner-friendly
- Easy to test
- Uses real financial analysis
- Demonstrates chatbot fundamentals

Limitations:
- No machine learning
- No natural language processing
- Cannot answer unexpected questions
- Requires exact query phrasing

Future Improvements:
- Add NLP support
- Build Flask web app
- Connect live financial APIs
- Expand query flexibility

Conclusion:
This prototype demonstrates how financial trend analysis can be converted into a functional AI-style chatbot for investor support and educational purposes.
"""

with open("documentation_summary.txt", "w") as file:
    file.write(documentation)

print("documentation_summary.txt created successfully!")
# Out:
# documentation_summary.txt created successfully!

# %%
import os

required_files = [
    "financial_chatbot.py",
    "financial_chatbot_task2.ipynb",
    "chatbot_test_results.txt",
    "documentation_summary.txt"
]

print("Submission File Check:\n")

for file in required_files:
    if file in os.listdir():
        print(f"✓ {file} found")
    else:
        print(f"✗ {file} missing")
# Out:
# Submission File Check:
#
# ✗ financial_chatbot.py missing
# ✓ financial_chatbot_task2.ipynb found
# ✓ chatbot_test_results.txt found
# ✓ documentation_summary.txt found

# %%
# Create missing financial_chatbot.py file

chatbot_code = '''
# Financial Chatbot Prototype
# Microsoft, Tesla, Apple (2023–2025)

def financial_chatbot(user_query):
    query = user_query.lower()

    if query == "what is microsoft's total revenue?":
        return "Microsoft's average total revenue (2023–2025) was $246.23 billion."

    elif query == "what is tesla's total revenue?":
        return "Tesla's average total revenue (2023–2025) was $96.43 billion."

    elif query == "what is apple's total revenue?":
        return "Apple's average total revenue (2023–2025) was $396.83 billion."

    elif query == "which company has the highest profit margin?":
        return "Microsoft had the highest average profit margin at 35.42%."

    elif query == "which company showed the strongest growth?":
        return "Microsoft showed the strongest overall growth from 2023–2025."

    elif query == "which company is the most stable?":
        return "Apple appeared the most stable due to consistent profitability."

    elif query == "which company is the most volatile?":
        return "Tesla showed the most volatility due to stagnant revenue and declining net income."

    elif query == "help":
        return """
Available Questions:
1. What is Microsoft's total revenue?
2. What is Tesla's total revenue?
3. What is Apple's total revenue?
4. Which company has the highest profit margin?
5. Which company showed the strongest growth?
6. Which company is the most stable?
7. Which company is the most volatile?
        """

    else:
        return "Sorry, I can only answer predefined financial questions."


# Chatbot Interface
print("Welcome to the Financial Chatbot Prototype!")
print("This chatbot analyzes Microsoft, Tesla, and Apple (2023–2025).")
print("Type 'help' to see available questions.")
print("Type 'exit' to quit.\\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    response = financial_chatbot(user_input)
    print("Chatbot:", response)
'''

# Save file
with open("financial_chatbot.py", "w") as file:
    file.write(chatbot_code)

print("✓ financial_chatbot.py created successfully!")

# Recheck all submission files
import os

required_files = [
    "financial_chatbot.py",
    "financial_chatbot_task2.ipynb",
    "chatbot_test_results.txt",
    "documentation_summary.txt"
]

print("\nUpdated Submission File Check:\n")

for file in required_files:
    if file in os.listdir():
        print(f"✓ {file} found")
    else:
        print(f"✗ {file} missing")

# Show current folder location
print("\nCurrent folder location:")
print(os.getcwd())
# Out:
# ✓ financial_chatbot.py created successfully!
#
# Updated Submission File Check:
#
# ✓ financial_chatbot.py found
# ✓ financial_chatbot_task2.ipynb found
# ✓ chatbot_test_results.txt found
# ✓ documentation_summary.txt found
#
# Current folder location:
# C:\Users\alekh
